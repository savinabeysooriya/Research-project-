# %%
from keras.applications.xception import Xception
from keras.preprocessing import image 
import tensorflow as tf 
import numpy as np
import os
from keras.applications.imagenet_utils import preprocess_input
from keras.applications.imagenet_utils import decode_predictions
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
data_path = '/content/drive/My Drive/A_Research_Project/Dataset/originals'
data_dir_list = os.listdir(data_path)

# %%
img_data_list = []

for dataclass in data_dir_list:
  img_list = os.listdir(data_path+"/"+dataclass)
  for img in img_list:
    img_path = data_path+"/"+dataclass+"/"+img
    img=image.load_img(img_path, target_size=(224, 224))
    x=image.img_to_array(img)
    x=np.expand_dims(x,axis=0)
    x=preprocess_input(x)
    img_data_list.append(x)

img_data=np.array(img_data_list)

# %%
img_data=np.rollaxis(img_data,1,0)
img_data= img_data[0]

# %%
num_classes=2
num_of_sample=250
labels=np.ones(250,dtype='int64')

# %%
labels[0:100]=0
labels[100:250]=1

names=['benign', 'malignant']

# %%
from keras.utils import np_utils
Y=np_utils.to_categorical(labels, num_classes)

# %%
from sklearn.utils import shuffle
x,y = shuffle(img_data, Y, random_state=2)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from keras.layers import Input, Dense, Flatten
from keras.models import Model

# %%
image_input = Input(shape=(224,224,3))

# %%
xception_model = Xception(input_tensor=image_input, weights='imagenet', include_top='True')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91889664/91884032 [==============================] - 1s 0us/step

# %%
last_layer = xception_model.get_layer('avg_pool').output
x=Flatten(name='flattern')(last_layer)
out=Dense(2, activation='sigmoid', name='output_layer')(x)

# %%
 model = Model(inputs = image_input, outputs=out)

# %%
for layer in model.layers[:-1]:
    layer.trainable = False

# %%
model.layers[-1].trainable
# Out:
# True

# %%
model.summary()

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
xy_train_datagen = ImageDataGenerator(rescale = 1./255, 
                                    shear_range = 0.2,
                                    zoom_range = 0.2,
                                    horizontal_flip = True)

# %%
xy_test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = xy_train_datagen.flow( X_train, y_train)

# %%
test_set = xy_test_datagen.flow(X_test, y_test)

# %%
r =model.fit_generator(training_set,  epochs=100,  steps_per_epoch= 7, validation_data=test_set)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 7/7 [==============================] - 55s 7s/step - loss: 0.6906 - accuracy: 0.5352 - val_loss: 0.6008 - val_accuracy: 0.7000
# Epoch 2/100
# 7/7 [==============================] - 51s 7s/step - loss: 0.6483 - accuracy: 0.5951 - val_loss: 0.5781 - val_accuracy: 0.7000
# Epoch 3/100
# 7/7 [==============================] - 51s 7s/step - loss: 0.6173 - accuracy: 0.6569 - val_loss: 0.5677 - val_accuracy: 0.8400
# Epoch 4/100
# 7/7 [==============================] - 57s 8s/step - loss: 0.5868 - accuracy: 0.7355 - val_loss: 0.5376 - val_accuracy: 0.8600
# Epoch 5/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.5909 - accuracy: 0.7329 - val_loss: 0.5267 - val_accuracy: 0.8800
# Epoch 6/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.5400 - accuracy: 0.8249 - val_loss: 0.5026 - val_accuracy: 0.8600
# Epoch 7/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.5387 - accuracy: 0.7224 - val_loss: 0.4742 - val_accuracy: 0.8600
# Epoch 8/100
# 7/7 [==============================] - 52s 7s/step - loss: 0
100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2738 - accuracy: 0.9036 - val_loss: 0.2537 - val_accuracy: 0.8800
# Epoch 62/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2462 - accuracy: 0.9555 - val_loss: 0.2474 - val_accuracy: 0.9200
# Epoch 63/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2756 - accuracy: 0.8930 - val_loss: 0.2451 - val_accuracy: 0.9200
# Epoch 64/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.2573 - accuracy: 0.9133 - val_loss: 0.2478 - val_accuracy: 0.9200
# Epoch 65/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.2617 - accuracy: 0.9105 - val_loss: 0.2493 - val_accuracy: 0.9000
# Epoch 66/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2764 - accuracy: 0.9179 - val_loss: 0.2530 - val_accuracy: 0.8600
# Epoch 67/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2388 - accuracy: 0.9495 - val_loss: 0.2523 - val_accuracy: 0.8600
# Epoch 68/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.2660 - accuracy: 0.9059 - val_loss: 0.2520 - val_accuracy: 0.8600
# Epoch 69/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2494 - accuracy: 0.9287 - val_loss: 0.2546 - val_accuracy: 0.8600
# Epoch 70/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.2170 - accuracy: 0.9490 - val_loss: 0.2521 - val_accuracy: 0.8600
# Epoch 71/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.2165 - accuracy: 0.9365 - val_loss: 0.2419 - val_accuracy: 0.9000
# Epoch 72/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.2457 - accuracy: 0.9423 - val_loss: 0.2383 - val_accuracy: 0.9200
# Epoch 73/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2595 - accuracy: 0.9192 - val_loss: 0.2420 - val_accuracy: 0.8600
# Epoch 74/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2278 - accuracy: 0.9665 - val_loss: 0.2454 - val_accuracy: 0.8600
# Epoch 75/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2145 - accuracy: 0.9592 - val_loss: 0.2415 - val_accuracy: 0.8600
# Epoch 76/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2582 - accuracy: 0.9045 - val_loss: 0.2313 - val_accuracy: 0.9200
# Epoch 77/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2428 - accuracy: 0.9422 - val_loss: 0.2334 - val_accuracy: 0.8800
# Epoch 78/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2189 - accuracy: 0.9472 - val_loss: 0.2383 - val_accuracy: 0.8600
# Epoch 79/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2585 - accuracy: 0.9494 - val_loss: 0.2380 - val_accuracy: 0.8600
# Epoch 80/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2684 - accuracy: 0.9226 - val_loss: 0.2383 - val_accuracy: 0.8600
# Epoch 81/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2789 - accuracy: 0.9161 - val_loss: 0.2344 - val_accuracy: 0.8600
# Epoch 82/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2140 - accuracy: 0.9499 - val_loss: 0.2383 - val_accuracy: 0.8600
# Epoch 83/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2563 - accuracy: 0.9239 - val_loss: 0.2327 - val_accuracy: 0.8600
# Epoch 84/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2314 - accuracy: 0.9399 - val_loss: 0.2346 - val_accuracy: 0.8600
# Epoch 85/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2408 - accuracy: 0.9300 - val_loss: 0.2304 - val_accuracy: 0.8600
# Epoch 86/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2218 - accuracy: 0.9457 - val_loss: 0.2256 - val_accuracy: 0.8600
# Epoch 87/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.1991 - accuracy: 0.9660 - val_loss: 0.2223 - val_accuracy: 0.9000
# Epoch 88/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2430 - accuracy: 0.8955 - val_loss: 0.2264 - val_accuracy: 0.8600
# Epoch 89/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2232 - accuracy: 0.9394 - val_loss: 0.2242 - val_accuracy: 0.8600
# Epoch 90/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2345 - accuracy: 0.9334 - val_loss: 0.2187 - val_accuracy: 0.9200
# Epoch 91/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2377 - accuracy: 0.9424 - val_loss: 0.2159 - val_accuracy: 0.9200
# Epoch 92/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2383 - accuracy: 0.9253 - val_loss: 0.2119 - val_accuracy: 0.9400
# Epoch 93/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.1943 - accuracy: 0.9630 - val_loss: 0.2132 - val_accuracy: 0.9200
# Epoch 94/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.2050 - accuracy: 0.9726 - val_loss: 0.2208 - val_accuracy: 0.8600
# Epoch 95/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.2349 - accuracy: 0.9167 - val_loss: 0.2263 - val_accuracy: 0.8600
# Epoch 96/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2229 - accuracy: 0.9366 - val_loss: 0.2216 - val_accuracy: 0.8600
# Epoch 97/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2600 - accuracy: 0.9223 - val_loss: 0.2187 - val_accuracy: 0.8800
# Epoch 98/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2007 - accuracy: 0.9416 - val_loss: 0.2128 - val_accuracy: 0.9000
# Epoch 99/100
# 7/7 [==============================] - 52s 8s/step - loss: 0.2626 - accuracy: 0.8827 - val_loss: 0.2157 - val_accuracy: 0.9000
# Epoch 100/100
# 7/7 [==============================] - 52s 7s/step - loss: 0.2076 - accuracy: 0.9510 - val_loss: 0.2191 - val_accuracy: 0.8600

# %%
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
scores = model.evaluate_generator(training_set,7) 
print("train_accuracy = ", scores[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# train_accuracy =  0.925000011920929

# %%
scores = model.evaluate_generator(test_set,7) 
print("val_accuracy = ", scores[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 7 batches). You may need to use the repeat() function when building your dataset.
# val_accuracy =  0.8600000143051147

# %%
prediction = model.predict_generator(test_set, steps=2 )
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
rounded_prediction = np.argmax(prediction, axis=-1)

# %%
true_categories_argmax = np.argmax(y_test, axis = 1)

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools

# %%
cm = confusion_matrix(y_true=true_categories_argmax , y_pred=rounded_prediction)

# %%
def plot_confusion_matrix(cm, num_classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(num_classes))
    plt.xticks(tick_marks, num_classes, rotation=45)
    plt.yticks(tick_marks, num_classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm_plot_labels = ['benign', 'malignant']

# %%
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[ 7  8]
#  [13 22]]

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(true_categories_argmax, rounded_prediction, target_names=cm_plot_labels)

# %%
 print(report)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.35      0.47      0.40        15
#    malignant       0.73      0.63      0.68        35
#
#     accuracy                           0.58        50
#    macro avg       0.54      0.55      0.54        50
# weighted avg       0.62      0.58      0.59        50

# %%
model.summary()
