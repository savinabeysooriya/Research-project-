# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image 
import numpy as np
import os
from keras.applications.imagenet_utils import preprocess_input
from keras.applications.imagenet_utils import decode_predictions
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
data_path = '/content/drive/My Drive/A_Research_Project/Dataset/originals'
data_dir_list = os.listdir(data_path)

# %%
img_data_list = []

for dataclass in data_dir_list:
  img_list = os.listdir(data_path+"/"+dataclass)
  for img in img_list:
    img_path = data_path+"/"+dataclass+"/"+img
    img=image.load_img(img_path, target_size=(224, 224))
    x=image.img_to_array(img)
    x=np.expand_dims(x,axis=0)
    x=preprocess_input(x)
    img_data_list.append(x)

img_data=np.array(img_data_list)

# %%
img_data=np.rollaxis(img_data,1,0)
img_data= img_data[0]

# %%
num_classes=2
num_of_sample=250
labels=np.ones(250,dtype='int64')

# %%
labels[0:100]=0
labels[100:250]=1

names=['benign', 'malignant']

# %%
from keras.utils import np_utils
Y=np_utils.to_categorical(labels, num_classes)

# %%
from sklearn.utils import shuffle
x,y = shuffle(img_data, Y, random_state=2)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from keras.layers import Input, Dense, Flatten
from keras.models import Model

# %%
image_input = Input(shape=(224,224,3))

# %%
vgg_model = VGG16(input_tensor=image_input, weights='imagenet', include_top='True')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 12s 0us/step

# %%
last_layer = vgg_model.get_layer('fc2').output
x=Flatten(name='flattern')(last_layer)
out=Dense(2, activation='sigmoid', name='output_layer')(x)

# %%
model = Model(inputs = image_input, outputs=out)

# %%
for layer in model.layers[:-1]:
    layer.trainable = False

# %%
model.layers[-1].trainable
# Out:
# True

# %%
model.summary()

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
xy_train_datagen = ImageDataGenerator(rescale = 1./255, 
                                    shear_range = 0.2,
                                    zoom_range = 0.2,
                                    horizontal_flip = True)

# %%
xy_test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = xy_train_datagen.flow( X_train, y_train)

# %%
test_set = xy_test_datagen.flow(X_test, y_test)

# %%
r =model.fit_generator(training_set,  epochs=100,  steps_per_epoch= 7, validation_data=test_set)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 7/7 [==============================] - 84s 12s/step - loss: 0.7912 - accuracy: 0.5103 - val_loss: 0.5821 - val_accuracy: 0.7000
# Epoch 2/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.6883 - accuracy: 0.5211 - val_loss: 0.5510 - val_accuracy: 0.7000
# Epoch 3/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.7112 - accuracy: 0.5388 - val_loss: 0.5854 - val_accuracy: 0.9200
# Epoch 4/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.5971 - accuracy: 0.7519 - val_loss: 0.4982 - val_accuracy: 0.7000
# Epoch 5/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.6127 - accuracy: 0.6177 - val_loss: 0.5850 - val_accuracy: 0.6800
# Epoch 6/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.5681 - accuracy: 0.8005 - val_loss: 0.4683 - val_accuracy: 0.9200
# Epoch 7/100
# 7/7 [==============================] - 85s 12s/step - loss: 0.5233 - accuracy: 0.7927 - val_loss: 0.4358 - val_accuracy: 0.8600
# Epoch 8/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.5344 - accuracy: 0.6724 - val_loss: 0.5631 - val_accuracy: 0.6800
# Epoch 9/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.5920 - accuracy: 0.6743 - val_loss: 0.4021 - val_accuracy: 0.7600
# Epoch 10/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.5250 - accuracy: 0.7342 - val_loss: 0.4690 - val_accuracy: 0.7000
# Epoch 11/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.5141 - accuracy: 0.7691 - val_loss: 0.3815 - val_accuracy: 0.9400
# Epoch 12/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4651 - accuracy: 0.8067 - val_loss: 0.4710 - val_accuracy: 0.7000
# Epoch 13/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4677 - accuracy: 0.7726 - val_loss: 0.3589 - val_accuracy: 0.9400
# Epoch 14/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4788 - accuracy: 0.7806 - val_loss: 0.4327 - val_accuracy: 0.7200
# Epoch 15/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4673 - accuracy: 0.8143 - val_loss: 0.3666 - val_accuracy: 0.9200
# Epoch 16/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4838 - accuracy: 0.7756 - val_loss: 0.3555 - val_accuracy: 0.9400
# Epoch 17/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4772 - accuracy: 0.7529 - val_loss: 0.3770 - val_accuracy: 0.8600
# Epoch 18/100
# 7/7 [==============================] - 81s 13s/step - loss: 0.4186 - accuracy: 0.8043 - val_loss: 0.3558 - val_accuracy: 0.9200
# Epoch 19/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4216 - accuracy: 0.8123 - val_loss: 0.3388 - val_accuracy: 0.9400
# Epoch 20/100
# 7/7 [==============================] - 81s 13s/step - loss: 0.4363 - accuracy: 0.8404 - val_loss: 0.3330 - val_accuracy: 0.9400
# Epoch 21/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4417 - accuracy: 0.7888 - val_loss: 0.3347 - val_accuracy: 0.9200
# Epoch 22/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3672 - accuracy: 0.8489 - val_loss: 0.3667 - val_accuracy: 0.8600
# Epoch 23/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4869 - accuracy: 0.7572 - val_loss: 0.3410 - val_accuracy: 0.9000
# Epoch 24/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.4058 - accuracy: 0.7983 - val_loss: 0.3037 - val_accuracy: 0.9600
# Epoch 25/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4299 - accuracy: 0.8097 - val_loss: 0.3579 - val_accuracy: 0.8600
# Epoch 26/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3688 - accuracy: 0.8559 - val_loss: 0.3155 - val_accuracy: 0.9200
# Epoch 27/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4281 - accuracy: 0.7897 - val_loss: 0.3097 - val_accuracy: 0.9200
# Epoch 28/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3993 - accuracy: 0.8458 - val_loss: 0.2894 - val_accuracy: 0.9600
# Epoch 29/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4268 - accuracy: 0.7789 - val_loss: 0.3469 - val_accuracy: 0.8600
# Epoch 30/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4147 - accuracy: 0.8316 - val_loss: 0.2846 - val_accuracy: 0.9600
# Epoch 31/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4277 - accuracy: 0.7847 - val_loss: 0.3562 - val_accuracy: 0.8400
# Epoch 32/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4019 - accuracy: 0.7947 - val_loss: 0.2788 - val_accuracy: 0.9600
# Epoch 33/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3815 - accuracy: 0.8339 - val_loss: 0.3180 - val_accuracy: 0.9000
# Epoch 34/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3973 - accuracy: 0.8393 - val_loss: 0.2776 - val_accuracy: 0.9600
# Epoch 35/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3810 - accuracy: 0.8106 - val_loss: 0.3386 - val_accuracy: 0.8600
# Epoch 36/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4000 - accuracy: 0.8215 - val_loss: 0.2689 - val_accuracy: 0.9600
# Epoch 37/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4251 - accuracy: 0.8080 - val_loss: 0.3756 - val_accuracy: 0.7000
# Epoch 38/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3484 - accuracy: 0.8361 - val_loss: 0.2667 - val_accuracy: 0.9400
# Epoch 39/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4357 - accuracy: 0.7653 - val_loss: 0.5207 - val_accuracy: 0.6800
# Epoch 40/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.5090 - accuracy: 0.7620 - val_loss: 0.2831 - val_accuracy: 0.8800
# Epoch 41/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4064 - accuracy: 0.7872 - val_loss: 0.3914 - val_accuracy: 0.7000
# Epoch 42/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4357 - accuracy: 0.8121 - val_loss: 0.2584 - val_accuracy: 0.9400
# Epoch 43/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3618 - accuracy: 0.8339 - val_loss: 0.3538 - val_accuracy: 0.7800
# Epoch 44/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3970 - accuracy: 0.8118 - val_loss: 0.2551 - val_accuracy: 0.9400
# Epoch 45/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3665 - accuracy: 0.8243 - val_loss: 0.4084 - val_accuracy: 0.7000
# Epoch 46/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3714 - accuracy: 0.8407 - val_loss: 0.2537 - val_accuracy: 0.9600
# Epoch 47/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4236 - accuracy: 0.7799 - val_loss: 0.2923 - val_accuracy: 0.9200
# Epoch 48/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3463 - accuracy: 0.8130 - val_loss: 0.3320 - val_accuracy: 0.8200
# Epoch 49/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3428 - accuracy: 0.8181 - val_loss: 0.2676 - val_accuracy: 0.9600
# Epoch 50/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4200 - accuracy: 0.7404 - val_loss: 0.3154 - val_accuracy: 0.8400
# Epoch 51/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3845 - accuracy: 0.8187 - val_loss: 0.2501 - val_accuracy: 0.9600
# Epoch 52/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3501 - accuracy: 0.8127 - val_loss: 0.3015 - val_accuracy: 0.9000
# Epoch 53/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4558 - accuracy: 0.7519 - val_loss: 0.2634 - val_accuracy: 0.9400
# Epoch 54/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3373 - accuracy: 0.8577 - val_loss: 0.2925 - val_accuracy: 0.9000
# Epoch 55/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3721 - accuracy: 0.8377 - val_loss: 0.2484 - val_accuracy: 0.9600
# Epoch 56/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3109 - accuracy: 0.8601 - val_loss: 0.3110 - val_accuracy: 0.8400
# Epoch 57/100
# 7/7 [==============================] - 82s 13s/step - loss: 0.3353 - accuracy: 0.8644 - val_loss: 0.2586 - val_accuracy: 0.9400
# Epoch 58/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.3195 - accuracy: 0.8649 - val_loss: 0.2759 - val_accuracy: 0.9200
# Epoch 59/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3650 - accuracy: 0.8064 - val_loss: 0.2806 - val_accuracy: 0.9200
# Epoch 60/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3418 - accuracy: 0.8593 - val_loss: 0.2498 - val_accuracy: 0.9200
# Epoch 61/100
# 7/7 [==============================] - 82s 13s/step - loss: 0.3976 - accuracy: 0.7952 - val_loss: 0.3304 - val_accuracy: 0.8200
# Epoch 62/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.3511 - accuracy: 0.8441 - val_loss: 0.2432 - val_accuracy: 0.9600
# Epoch 63/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.3187 - accuracy: 0.8439 - val_loss: 0.3043 - val_accuracy: 0.8800
# Epoch 64/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.3780 - accuracy: 0.8297 - val_loss: 0.2675 - val_accuracy: 0.9600
# Epoch 65/100
# 7/7 [==============================] - 82s 13s/step - loss: 0.3592 - accuracy: 0.8528 - val_loss: 0.2660 - val_accuracy: 0.9600
# Epoch 66/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4304 - accuracy: 0.7542 - val_loss: 0.2532 - val_accuracy: 0.9200
# Epoch 67/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3422 - accuracy: 0.8346 - val_loss: 0.2403 - val_accuracy: 0.9600
# Epoch 68/100
# 7/7 [==============================] - 82s 13s/step - loss: 0.3199 - accuracy: 0.8759 - val_loss: 0.2953 - val_accuracy: 0.9000
# Epoch 69/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.3096 - accuracy: 0.8341 - val_loss: 0.2406 - val_accuracy: 0.9200
# Epoch 70/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.3376 - accuracy: 0.8282 - val_loss: 0.3986 - val_accuracy: 0.7000
# Epoch 71/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.4638 - accuracy: 0.8065 - val_loss: 0.2414 - val_accuracy: 0.9400
# Epoch 72/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3407 - accuracy: 0.8423 - val_loss: 0.2878 - val_accuracy: 0.9000
# Epoch 73/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.3431 - accuracy: 0.8432 - val_loss: 0.2354 - val_accuracy: 0.9600
# Epoch 74/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.3816 - accuracy: 0.8036 - val_loss: 0.2869 - val_accuracy: 0.9000
# Epoch 75/100
# 7/7 [==============================] - 82s 12s/step - loss: 0.3823 - accuracy: 0.7926 - val_loss: 0.2339 - val_accuracy: 0.9600
# Epoch 76/100
# 7/7 [==============================] - 81s 13s/step - loss: 0.3205 - accuracy: 0.8560 - val_loss: 0.3041 - val_accuracy: 0.8200
# Epoch 77/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3283 - accuracy: 0.8268 - val_loss: 0.2320 - val_accuracy: 0.9600
# Epoch 78/100
# 7/7 [==============================] - 80s 12s/step - loss: 0.3631 - accuracy: 0.8429 - val_loss: 0.3210 - val_accuracy: 0.7800
# Epoch 79/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3501 - accuracy: 0.8912 - val_loss: 0.2335 - val_accuracy: 0.9200
# Epoch 80/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.2967 - accuracy: 0.8667 - val_loss: 0.3218 - val_accuracy: 0.7800
# Epoch 81/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3809 - accuracy: 0.8102 - val_loss: 0.2419 - val_accuracy: 0.9200
# Epoch 82/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3983 - accuracy: 0.8012 - val_loss: 0.3452 - val_accuracy: 0.7600
# Epoch 83/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3285 - accuracy: 0.8580 - val_loss: 0.2329 - val_accuracy: 0.9400
# Epoch 84/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3675 - accuracy: 0.8280 - val_loss: 0.2601 - val_accuracy: 0.9600
# Epoch 85/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3828 - accuracy: 0.8192 - val_loss: 0.2462 - val_accuracy: 0.9200
# Epoch 86/100
# 7/7 [==============================] - 80s 12s/step - loss: 0.3346 - accuracy: 0.8082 - val_loss: 0.2721 - val_accuracy: 0.9000
# Epoch 87/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3644 - accuracy: 0.8360 - val_loss: 0.2439 - val_accuracy: 0.9200
# Epoch 88/100
# 7/7 [==============================] - 81s 13s/step - loss: 0.3738 - accuracy: 0.8103 - val_loss: 0.2451 - val_accuracy: 0.9400
# Epoch 89/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3267 - accuracy: 0.8473 - val_loss: 0.2355 - val_accuracy: 0.9400
# Epoch 90/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3435 - accuracy: 0.8393 - val_loss: 0.2651 - val_accuracy: 0.9400
# Epoch 91/100
# 7/7 [==============================] - 81s 13s/step - loss: 0.3363 - accuracy: 0.8419 - val_loss: 0.2343 - val_accuracy: 0.9400
# Epoch 92/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3122 - accuracy: 0.8740 - val_loss: 0.2537 - val_accuracy: 0.9400
# Epoch 93/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3528 - accuracy: 0.8016 - val_loss: 0.2622 - val_accuracy: 0.9400
# Epoch 94/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3282 - accuracy: 0.8661 - val_loss: 0.2474 - val_accuracy: 0.9400
# Epoch 95/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3458 - accuracy: 0.8581 - val_loss: 0.2689 - val_accuracy: 0.9400
# Epoch 96/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3394 - accuracy: 0.8532 - val_loss: 0.2482 - val_accuracy: 0.9400
# Epoch 97/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3357 - accuracy: 0.8396 - val_loss: 0.2632 - val_accuracy: 0.9400
# Epoch 98/100
# 7/7 [==============================] - 81s 13s/step - loss: 0.3354 - accuracy: 0.8690 - val_loss: 0.2411 - val_accuracy: 0.9400
# Epoch 99/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.2594 - accuracy: 0.9110 - val_loss: 0.2569 - val_accuracy: 0.9400
# Epoch 100/100
# 7/7 [==============================] - 81s 12s/step - loss: 0.3754 - accuracy: 0.8420 - val_loss: 0.2374 - val_accuracy: 0.9400

# %%
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
scores = model.evaluate_generator(training_set,7) 
print("train_accuracy = ", scores[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# train_accuracy =  0.8500000238418579

# %%
scores = model.evaluate_generator(test_set,7) 
print("test_accuracy = ", scores[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 7 batches). You may need to use the repeat() function when building your dataset.
# val_accuracy =  0.9399999976158142

# %%
prediction = model.predict_generator(test_set, steps=2 )
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
rounded_prediction = np.argmax(prediction, axis=-1)

# %%
true_categories_argmax = np.argmax(y_test, axis = 1)

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools

# %%
cm = confusion_matrix(y_true=true_categories_argmax , y_pred=rounded_prediction)

# %%
def plot_confusion_matrix(cm, num_classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(num_classes))
    plt.xticks(tick_marks, num_classes, rotation=45)
    plt.yticks(tick_marks, num_classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm_plot_labels = ['benign', 'malignant']

# %%
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[ 3 12]
#  [11 24]]

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(true_categories_argmax, rounded_prediction, target_names=cm_plot_labels)

# %%
 print(report)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.21      0.20      0.21        15
#    malignant       0.67      0.69      0.68        35
#
#     accuracy                           0.54        50
#    macro avg       0.44      0.44      0.44        50
# weighted avg       0.53      0.54      0.54        50
