# %%
from keras.applications.resnet import ResNet50
from keras.preprocessing import image 
import tensorflow as tf 
import numpy as np
import os
from keras.applications.imagenet_utils import preprocess_input
from keras.applications.imagenet_utils import decode_predictions
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
data_path = '/content/drive/MyDrive/A_Research_Project/Dataset/Dataset_B'
data_dir_list = os.listdir(data_path)

# %%
img_data_list = []

for dataclass in data_dir_list:
  img_list = os.listdir(data_path+"/"+dataclass)
  for img in img_list:
    img_path = data_path+"/"+dataclass+"/"+img
    img=image.load_img(img_path, target_size=(224, 224))
    x=image.img_to_array(img)
    x=np.expand_dims(x,axis=0)
    x=preprocess_input(x)
    img_data_list.append(x)

img_data=np.array(img_data_list)

# %%
img_data=np.rollaxis(img_data,1,0)
img_data= img_data[0]

# %%
num_classes=2
num_of_sample=646
labels=np.ones(646,dtype='int64')

# %%
labels[0:437]=0
labels[437:646]=1

names=['benign', 'malignant']

# %%
from keras.utils import np_utils
Y=np_utils.to_categorical(labels, num_classes)

# %%
from sklearn.utils import shuffle
x,y = shuffle(img_data, Y, random_state=2)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=5)

# %%
from keras.layers import Input, Dense, Flatten
from keras.models import Model

# %%
image_input = Input(shape=(224,224,3))

# %%
resnet_model = ResNet50(input_tensor=image_input, weights='imagenet', include_top='True')

# %%
last_layer = resnet_model.get_layer('avg_pool').output
x=Flatten(name='flattern')(last_layer)
out=Dense(2, activation='sigmoid', name='output_layer')(x)

# %%
model = Model(inputs = image_input, outputs=out)

# %%
for layer in model.layers[:-1]:
    layer.trainable = False

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
xy_train_datagen = ImageDataGenerator(rescale = 1./255, 
                                    shear_range = 0.2,
                                    zoom_range = 0.2,
                                    horizontal_flip = True)

# %%
xy_test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = xy_train_datagen.flow( X_train, y_train)

# %%
test_set = xy_test_datagen.flow(X_test, y_test)

# %%
r =model.fit_generator(training_set,  epochs=100,  steps_per_epoch= 17, validation_data=test_set)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 17/17 [==============================] - 105s 6s/step - loss: 0.6877 - accuracy: 0.6694 - val_loss: 0.6255 - val_accuracy: 0.7000
# Epoch 2/100
# 17/17 [==============================] - 105s 6s/step - loss: 0.6519 - accuracy: 0.6446 - val_loss: 0.6083 - val_accuracy: 0.7000
# Epoch 3/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6369 - accuracy: 0.6604 - val_loss: 0.6016 - val_accuracy: 0.7000
# Epoch 4/100
# 17/17 [==============================] - 102s 6s/step - loss: 0.6228 - accuracy: 0.6829 - val_loss: 0.5991 - val_accuracy: 0.7000
# Epoch 5/100
# 17/17 [==============================] - 102s 6s/step - loss: 0.6476 - accuracy: 0.6446 - val_loss: 0.5952 - val_accuracy: 0.7000
# Epoch 6/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6316 - accuracy: 0.6633 - val_loss: 0.5920 - val_accuracy: 0.7000
# Epoch 7/100
# 17/17 [==============================] - 102s 6s/step - loss: 0.6067 - accuracy: 0.6974 - val_loss: 0.6107 - val_accuracy: 0.7000
# Epoch 8/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6311 - accuracy: 0.6719 - val_loss: 0.5883 - val_accuracy: 0.7000
# Epoch 9/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6106 - accuracy: 0.6947 - val_loss: 0.5927 - val_accuracy: 0.7000
# Epoch 10/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6100 - accuracy: 0.6949 - val_loss: 0.5833 - val_accuracy: 0.7000
# Epoch 11/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6050 - accuracy: 0.6837 - val_loss: 0.5869 - val_accuracy: 0.7000
# Epoch 12/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6242 - accuracy: 0.6542 - val_loss: 0.5749 - val_accuracy: 0.7000
# Epoch 13/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6123 - accuracy: 0.6718 - val_loss: 0.5726 - val_accuracy: 0.7000
# Epoch 14/100
# 17/17 [==============================] - 102s 6s/step - loss: 0.6193 - accuracy: 0.6601 - val_loss: 0.5704 - val_accuracy: 0.7000
# Epoch 15/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6062 - accuracy: 0.6697 - val_loss: 0.5675 - val_accuracy: 0.7000
# Epoch 16/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6008 - accuracy: 0.6875 - val_loss: 0.5724 - val_accuracy: 0.7000
# Epoch 17/100
# 17/17 [==============================] - 102s 6s/step - loss: 0.6005 - accuracy: 0.6848 - val_loss: 0.5623 - val_accuracy: 0.7000
# Epoch 18/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6138 - accuracy: 0.6572 - val_loss: 0.5599 - val_accuracy: 0.7000
# Epoch 19/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5948 - accuracy: 0.6847 - val_loss: 0.5641 - val_accuracy: 0.7000
# Epoch 20/100
# 17/17 [==============================] - 102s 6s/step - loss: 0.6157 - accuracy: 0.6321 - val_loss: 0.5709 - val_accuracy: 0.7000
# Epoch 21/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6422 - accuracy: 0.6505 - val_loss: 0.5586 - val_accuracy: 0.7000
# Epoch 22/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6161 - accuracy: 0.6371 - val_loss: 0.5502 - val_accuracy: 0.7000
# Epoch 23/100
# 17/17 [==============================] - 102s 6s/step - loss: 0.5992 - accuracy: 0.6625 - val_loss: 0.5505 - val_accuracy: 0.7000
# Epoch 24/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5782 - accuracy: 0.6855 - val_loss: 0.5461 - val_accuracy: 0.7000
# Epoch 25/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5755 - accuracy: 0.6983 - val_loss: 0.5483 - val_accuracy: 0.7000
# Epoch 26/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5794 - accuracy: 0.6855 - val_loss: 0.5418 - val_accuracy: 0.7000
# Epoch 27/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5874 - accuracy: 0.6936 - val_loss: 0.5402 - val_accuracy: 0.7000
# Epoch 28/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5757 - accuracy: 0.6924 - val_loss: 0.5382 - val_accuracy: 0.7000
# Epoch 29/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6049 - accuracy: 0.6418 - val_loss: 0.5366 - val_accuracy: 0.7000
# Epoch 30/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6024 - accuracy: 0.6523 - val_loss: 0.5342 - val_accuracy: 0.7000
# Epoch 31/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5765 - accuracy: 0.6833 - val_loss: 0.5346 - val_accuracy: 0.7000
# Epoch 32/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.6038 - accuracy: 0.6473 - val_loss: 0.5363 - val_accuracy: 0.7000
# Epoch 33/100
# 17/17 [==============================] - 102s 6s/step - loss: 0.5781 - accuracy: 0.6896 - val_loss: 0.5425 - val_accuracy: 0.7385
# Epoch 34/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5897 - accuracy: 0.7081 - val_loss: 0.5294 - val_accuracy: 0.7000
# Epoch 35/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.6033 - accuracy: 0.6692 - val_loss: 0.5270 - val_accuracy: 0.7000
# Epoch 36/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5958 - accuracy: 0.6622 - val_loss: 0.5249 - val_accuracy: 0.7000
# Epoch 37/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5874 - accuracy: 0.6699 - val_loss: 0.5299 - val_accuracy: 0.7154
# Epoch 38/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5805 - accuracy: 0.6780 - val_loss: 0.5302 - val_accuracy: 0.7000
# Epoch 39/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5702 - accuracy: 0.6744 - val_loss: 0.5265 - val_accuracy: 0.7154
# Epoch 40/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5663 - accuracy: 0.6810 - val_loss: 0.5194 - val_accuracy: 0.7077
# Epoch 41/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5734 - accuracy: 0.6938 - val_loss: 0.5175 - val_accuracy: 0.7000
# Epoch 42/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5825 - accuracy: 0.6565 - val_loss: 0.5160 - val_accuracy: 0.7077
# Epoch 43/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5899 - accuracy: 0.6683 - val_loss: 0.5147 - val_accuracy: 0.7077
# Epoch 44/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5728 - accuracy: 0.6724 - val_loss: 0.5158 - val_accuracy: 0.7154
# Epoch 45/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5845 - accuracy: 0.6810 - val_loss: 0.5120 - val_accuracy: 0.7077
# Epoch 46/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5537 - accuracy: 0.6926 - val_loss: 0.5298 - val_accuracy: 0.8538
# Epoch 47/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5856 - accuracy: 0.7016 - val_loss: 0.5208 - val_accuracy: 0.7000
# Epoch 48/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5970 - accuracy: 0.6675 - val_loss: 0.5123 - val_accuracy: 0.7385
# Epoch 49/100
# 17/17 [==============================] - 102s 6s/step - loss: 0.5642 - accuracy: 0.6985 - val_loss: 0.5074 - val_accuracy: 0.7154
# Epoch 50/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5715 - accuracy: 0.6941 - val_loss: 0.5064 - val_accuracy: 0.7077
# Epoch 51/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5606 - accuracy: 0.6623 - val_loss: 0.5076 - val_accuracy: 0.7385
# Epoch 52/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5643 - accuracy: 0.6984 - val_loss: 0.5058 - val_accuracy: 0.7077
# Epoch 53/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5934 - accuracy: 0.6815 - val_loss: 0.5021 - val_accuracy: 0.7077
# Epoch 54/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5860 - accuracy: 0.6641 - val_loss: 0.5010 - val_accuracy: 0.7154
# Epoch 55/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5714 - accuracy: 0.6988 - val_loss: 0.5102 - val_accuracy: 0.7000
# Epoch 56/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5760 - accuracy: 0.6680 - val_loss: 0.5012 - val_accuracy: 0.7462
# Epoch 57/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5602 - accuracy: 0.6913 - val_loss: 0.4977 - val_accuracy: 0.7154
# Epoch 58/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5459 - accuracy: 0.7152 - val_loss: 0.4975 - val_accuracy: 0.7385
# Epoch 59/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5623 - accuracy: 0.6976 - val_loss: 0.4956 - val_accuracy: 0.7154
# Epoch 60/100
# 17/17 [==============================] - 102s 6s/step - loss: 0.5436 - accuracy: 0.7097 - val_loss: 0.4948 - val_accuracy: 0.7154
# Epoch 61/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5339 - accuracy: 0.7412 - val_loss: 0.4986 - val_accuracy: 0.7846
# Epoch 62/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5780 - accuracy: 0.7350 - val_loss: 0.4934 - val_accuracy: 0.7077
# Epoch 63/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5495 - accuracy: 0.7122 - val_loss: 0.4926 - val_accuracy: 0.7385
# Epoch 64/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5652 - accuracy: 0.7099 - val_loss: 0.4913 - val_accuracy: 0.7154
# Epoch 65/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5858 - accuracy: 0.6619 - val_loss: 0.4904 - val_accuracy: 0.7154
# Epoch 66/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5659 - accuracy: 0.6681 - val_loss: 0.4907 - val_accuracy: 0.7154
# Epoch 67/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5733 - accuracy: 0.6556 - val_loss: 0.4882 - val_accuracy: 0.7308
# Epoch 68/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5513 - accuracy: 0.7125 - val_loss: 0.4906 - val_accuracy: 0.7923
# Epoch 69/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5775 - accuracy: 0.7294 - val_loss: 0.4893 - val_accuracy: 0.7154
# Epoch 70/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5588 - accuracy: 0.6729 - val_loss: 0.4861 - val_accuracy: 0.7692
# Epoch 71/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5510 - accuracy: 0.7383 - val_loss: 0.4855 - val_accuracy: 0.7846
# Epoch 72/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5536 - accuracy: 0.7382 - val_loss: 0.4839 - val_accuracy: 0.7154
# Epoch 73/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5397 - accuracy: 0.7095 - val_loss: 0.4983 - val_accuracy: 0.8615
# Epoch 74/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5572 - accuracy: 0.7057 - val_loss: 0.4857 - val_accuracy: 0.7077
# Epoch 75/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5650 - accuracy: 0.7094 - val_loss: 0.4815 - val_accuracy: 0.7538
# Epoch 76/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5247 - accuracy: 0.7644 - val_loss: 0.4810 - val_accuracy: 0.7846
# Epoch 77/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5586 - accuracy: 0.6912 - val_loss: 0.4824 - val_accuracy: 0.7154
# Epoch 78/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5638 - accuracy: 0.7155 - val_loss: 0.4796 - val_accuracy: 0.7385
# Epoch 79/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5610 - accuracy: 0.6800 - val_loss: 0.4801 - val_accuracy: 0.7923
# Epoch 80/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5697 - accuracy: 0.7144 - val_loss: 0.4820 - val_accuracy: 0.7154
# Epoch 81/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5248 - accuracy: 0.7156 - val_loss: 0.4800 - val_accuracy: 0.8154
# Epoch 82/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5305 - accuracy: 0.7512 - val_loss: 0.4765 - val_accuracy: 0.7385
# Epoch 83/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5452 - accuracy: 0.7174 - val_loss: 0.4818 - val_accuracy: 0.8538
# Epoch 84/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5387 - accuracy: 0.7945 - val_loss: 0.4808 - val_accuracy: 0.7077
# Epoch 85/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5372 - accuracy: 0.6922 - val_loss: 0.4761 - val_accuracy: 0.7923
# Epoch 86/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5662 - accuracy: 0.7330 - val_loss: 0.4832 - val_accuracy: 0.7154
# Epoch 87/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5466 - accuracy: 0.6985 - val_loss: 0.4739 - val_accuracy: 0.7846
# Epoch 88/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5610 - accuracy: 0.7194 - val_loss: 0.4746 - val_accuracy: 0.7385
# Epoch 89/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5529 - accuracy: 0.7294 - val_loss: 0.4738 - val_accuracy: 0.7385
# Epoch 90/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5458 - accuracy: 0.6720 - val_loss: 0.4720 - val_accuracy: 0.7846
# Epoch 91/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5558 - accuracy: 0.7185 - val_loss: 0.4720 - val_accuracy: 0.7385
# Epoch 92/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5393 - accuracy: 0.7110 - val_loss: 0.4724 - val_accuracy: 0.8308
# Epoch 93/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5408 - accuracy: 0.7431 - val_loss: 0.4703 - val_accuracy: 0.7538
# Epoch 94/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5624 - accuracy: 0.7095 - val_loss: 0.4703 - val_accuracy: 0.7385
# Epoch 95/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5403 - accuracy: 0.7194 - val_loss: 0.4750 - val_accuracy: 0.7154
# Epoch 96/100
# 17/17 [==============================] - 100s 6s/step - loss: 0.5604 - accuracy: 0.7236 - val_loss: 0.4795 - val_accuracy: 0.8615
# Epoch 97/100
# 17/17 [==============================] - 102s 6s/step - loss: 0.5714 - accuracy: 0.6855 - val_loss: 0.4731 - val_accuracy: 0.7154
# Epoch 98/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5703 - accuracy: 0.6737 - val_loss: 0.4772 - val_accuracy: 0.7077
# Epoch 99/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5191 - accuracy: 0.7197 - val_loss: 0.4721 - val_accuracy: 0.8692
# Epoch 100/100
# 17/17 [==============================] - 101s 6s/step - loss: 0.5505 - accuracy: 0.7488 - val_loss: 0.4721 - val_accuracy: 0.7154

# %%
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
scores = model.evaluate_generator(training_set,17) 
print("train_accuracy = ", scores[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# train_accuracy =  0.6996123790740967

# %%
scores = model.evaluate_generator(test_set,17) 
print("test_accuracy = ", scores[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 17 batches). You may need to use the repeat() function when building your dataset.
# test_accuracy =  0.7153846025466919

# %%
prediction = model.predict_generator(test_set, steps=5 )
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
rounded_prediction = np.argmax(prediction, axis=-1)

# %%
true_categories_argmax = np.argmax(y_test, axis = 1)

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools

# %%
cm = confusion_matrix(y_true=true_categories_argmax , y_pred=rounded_prediction)

# %%
def plot_confusion_matrix(cm, num_classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(num_classes))
    plt.xticks(tick_marks, num_classes, rotation=45)
    plt.yticks(tick_marks, num_classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm_plot_labels = ['benign', 'malignant']

# %%
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[89  2]
#  [37  2]]

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(true_categories_argmax, rounded_prediction, target_names=cm_plot_labels)

# %%
 print(report)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.71      0.98      0.82        91
#    malignant       0.50      0.05      0.09        39
#
#     accuracy                           0.70       130
#    macro avg       0.60      0.51      0.46       130
# weighted avg       0.64      0.70      0.60       130
