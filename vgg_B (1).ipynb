# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image 
import numpy as np
import os
from keras.applications.imagenet_utils import preprocess_input
from keras.applications.imagenet_utils import decode_predictions
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
data_path = '/content/drive/MyDrive/A_Research_Project/Dataset/Dataset_B'
data_dir_list = os.listdir(data_path)

# %%
img_data_list = []

for dataclass in data_dir_list:
  img_list = os.listdir(data_path+"/"+dataclass)
  for img in img_list:
    img_path = data_path+"/"+dataclass+"/"+img
    img=image.load_img(img_path, target_size=(224, 224))
    x=image.img_to_array(img)
    x=np.expand_dims(x,axis=0)
    x=preprocess_input(x)
    img_data_list.append(x)

img_data=np.array(img_data_list)

# %%
img_data=np.rollaxis(img_data,1,0)
img_data= img_data[0]

# %%
num_classes=2
num_of_sample=646
labels=np.ones(646,dtype='int64')

# %%
labels[0:437]=0
labels[437:646]=1

names=['benign', 'malignant']

# %%
from keras.utils import np_utils
Y=np_utils.to_categorical(labels, num_classes)

# %%
from sklearn.utils import shuffle
x,y = shuffle(img_data, Y, random_state=3)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=3)

# %%
from keras.layers import Input, Dense, Flatten
from keras.models import Model

# %%
image_input = Input(shape=(224,224,3))

# %%
vgg_model = VGG16(input_tensor=image_input, weights='imagenet', include_top='True')

# %%
last_layer = vgg_model.get_layer('fc2').output
x=Flatten(name='flattern')(last_layer)
out=Dense(2, activation='sigmoid', name='output_layer')(x)

# %%
model = Model(inputs = image_input, outputs=out)

# %%
for layer in model.layers[:-1]:
    layer.trainable = False

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
xy_train_datagen = ImageDataGenerator(rescale = 1./255, 
                                    shear_range = 0.2,
                                    zoom_range = 0.2,
                                    horizontal_flip = True)

# %%
xy_test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = xy_train_datagen.flow( X_train, y_train)

# %%
test_set = xy_test_datagen.flow(X_test, y_test)

# %%
r =model.fit_generator(training_set,  epochs=100,  steps_per_epoch= 7, validation_data=test_set)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 7/7 [==============================] - 177s 27s/step - loss: 0.6749 - accuracy: 0.7015 - val_loss: 0.7637 - val_accuracy: 0.3308
# Epoch 2/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.7279 - accuracy: 0.5215 - val_loss: 0.6457 - val_accuracy: 0.6692
# Epoch 3/100
# 7/7 [==============================] - 166s 27s/step - loss: 0.5747 - accuracy: 0.7570 - val_loss: 0.6659 - val_accuracy: 0.6692
# Epoch 4/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.5364 - accuracy: 0.7627 - val_loss: 0.6516 - val_accuracy: 0.7231
# Epoch 5/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.6839 - accuracy: 0.6104 - val_loss: 0.7105 - val_accuracy: 0.6692
# Epoch 6/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.6359 - accuracy: 0.7130 - val_loss: 0.5797 - val_accuracy: 0.6769
# Epoch 7/100
# 7/7 [==============================] - 165s 24s/step - loss: 0.6625 - accuracy: 0.5626 - val_loss: 0.5745 - val_accuracy: 0.7000
# Epoch 8/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.6450 - accuracy: 0.6116 - val_loss: 0.6066 - val_accuracy: 0.6692
# Epoch 9/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.
100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4212 - accuracy: 0.8219 - val_loss: 0.4797 - val_accuracy: 0.7462
# Epoch 61/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4666 - accuracy: 0.8111 - val_loss: 0.4714 - val_accuracy: 0.7692
# Epoch 62/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4622 - accuracy: 0.7759 - val_loss: 0.4739 - val_accuracy: 0.8077
# Epoch 63/100
# 7/7 [==============================] - 162s 27s/step - loss: 0.5206 - accuracy: 0.7497 - val_loss: 0.4692 - val_accuracy: 0.7692
# Epoch 64/100
# 7/7 [==============================] - 162s 27s/step - loss: 0.5022 - accuracy: 0.7595 - val_loss: 0.4691 - val_accuracy: 0.7923
# Epoch 65/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4545 - accuracy: 0.8002 - val_loss: 0.4710 - val_accuracy: 0.7923
# Epoch 66/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4679 - accuracy: 0.7914 - val_loss: 0.4703 - val_accuracy: 0.7692
# Epoch 67/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.5166 - accuracy: 0.7295 - val_loss: 0.4869 - val_accuracy: 0.7923
# Epoch 68/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.4596 - accuracy: 0.8338 - val_loss: 0.4855 - val_accuracy: 0.7462
# Epoch 69/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4868 - accuracy: 0.7882 - val_loss: 0.4710 - val_accuracy: 0.8000
# Epoch 70/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4669 - accuracy: 0.7850 - val_loss: 0.4714 - val_accuracy: 0.7692
# Epoch 71/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.4980 - accuracy: 0.7348 - val_loss: 0.4837 - val_accuracy: 0.7846
# Epoch 72/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.4942 - accuracy: 0.7809 - val_loss: 0.5255 - val_accuracy: 0.7231
# Epoch 73/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.5214 - accuracy: 0.7244 - val_loss: 0.4889 - val_accuracy: 0.7769
# Epoch 74/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4692 - accuracy: 0.7659 - val_loss: 0.5164 - val_accuracy: 0.7231
# Epoch 75/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.4130 - accuracy: 0.8169 - val_loss: 0.4644 - val_accuracy: 0.8154
# Epoch 76/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.5219 - accuracy: 0.7440 - val_loss: 0.4676 - val_accuracy: 0.8000
# Epoch 77/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.5094 - accuracy: 0.7264 - val_loss: 0.4800 - val_accuracy: 0.7462
# Epoch 78/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.5357 - accuracy: 0.7571 - val_loss: 0.5026 - val_accuracy: 0.7769
# Epoch 79/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.5023 - accuracy: 0.7832 - val_loss: 0.4612 - val_accuracy: 0.8077
# Epoch 80/100
# 7/7 [==============================] - 162s 27s/step - loss: 0.4793 - accuracy: 0.7709 - val_loss: 0.4680 - val_accuracy: 0.7692
# Epoch 81/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4326 - accuracy: 0.7570 - val_loss: 0.4595 - val_accuracy: 0.8231
# Epoch 82/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.5015 - accuracy: 0.7614 - val_loss: 0.4662 - val_accuracy: 0.7615
# Epoch 83/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4283 - accuracy: 0.8151 - val_loss: 0.4599 - val_accuracy: 0.7846
# Epoch 84/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.4241 - accuracy: 0.8396 - val_loss: 0.4607 - val_accuracy: 0.8154
# Epoch 85/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.4769 - accuracy: 0.8063 - val_loss: 0.4600 - val_accuracy: 0.8154
# Epoch 86/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4728 - accuracy: 0.7682 - val_loss: 0.4601 - val_accuracy: 0.8154
# Epoch 87/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4633 - accuracy: 0.8043 - val_loss: 0.4596 - val_accuracy: 0.8154
# Epoch 88/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.4713 - accuracy: 0.8370 - val_loss: 0.4710 - val_accuracy: 0.7615
# Epoch 89/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4570 - accuracy: 0.7814 - val_loss: 0.4581 - val_accuracy: 0.7923
# Epoch 90/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4253 - accuracy: 0.8203 - val_loss: 0.4734 - val_accuracy: 0.7769
# Epoch 91/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4545 - accuracy: 0.8340 - val_loss: 0.4629 - val_accuracy: 0.7615
# Epoch 92/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.4230 - accuracy: 0.8238 - val_loss: 0.4595 - val_accuracy: 0.8077
# Epoch 93/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4336 - accuracy: 0.7914 - val_loss: 0.4676 - val_accuracy: 0.7692
# Epoch 94/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.4742 - accuracy: 0.7653 - val_loss: 0.4584 - val_accuracy: 0.8077
# Epoch 95/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.4911 - accuracy: 0.7302 - val_loss: 0.4553 - val_accuracy: 0.7692
# Epoch 96/100
# 7/7 [==============================] - 162s 24s/step - loss: 0.4048 - accuracy: 0.8136 - val_loss: 0.4598 - val_accuracy: 0.7692
# Epoch 97/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4134 - accuracy: 0.7883 - val_loss: 0.4476 - val_accuracy: 0.8231
# Epoch 98/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4256 - accuracy: 0.8534 - val_loss: 0.4488 - val_accuracy: 0.8000
# Epoch 99/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4522 - accuracy: 0.8034 - val_loss: 0.4475 - val_accuracy: 0.8077
# Epoch 100/100
# 7/7 [==============================] - 176s 27s/step - loss: 0.4628 - accuracy: 0.8119 - val_loss: 0.4567 - val_accuracy: 0.7615

# %%
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
scores = model.evaluate_generator(training_set,17) 
print("train_accuracy = ", scores[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# train_accuracy =  0.7635658979415894

# %%
scores = model.evaluate_generator(test_set,17) 
print("test_accuracy = ", scores[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 17 batches). You may need to use the repeat() function when building your dataset.
# test_accuracy =  0.7615384459495544

# %%
prediction = model.predict_generator(test_set, steps=5 )
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
rounded_prediction = np.argmax(prediction, axis=-1)

# %%
true_categories_argmax = np.argmax(y_test, axis = 1)

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools

# %%
cm = confusion_matrix(y_true=true_categories_argmax , y_pred=rounded_prediction)

# %%
def plot_confusion_matrix(cm, num_classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(num_classes))
    plt.xticks(tick_marks, num_classes, rotation=45)
    plt.yticks(tick_marks, num_classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm_plot_labels = ['benign', 'malignant']

# %%
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[72 15]
#  [36  7]]

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(true_categories_argmax, rounded_prediction, target_names=cm_plot_labels)

# %%
 print(report)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.67      0.83      0.74        87
#    malignant       0.32      0.16      0.22        43
#
#     accuracy                           0.61       130
#    macro avg       0.49      0.50      0.48       130
# weighted avg       0.55      0.61      0.57       130

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# flattern (Flatten)           (None, 4096)              0
# _________________________________________________________________
# output_layer (Dense)         (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 8,194
# Non-trainable params: 134,260,544
# _________________________________________________________________
